# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-bf1647b42bbd> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount("/content/drive")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     285             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     286         )
# --> 287       raise ValueError('mount failed' + extra_reason)
# ...

# %%
# !nvidia-smi
# Out:
# Wed May 22 11:26:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# %cd /content/drive/MyDrive/yolov8 v3
# Out:
# /content/drive/MyDrive/yolov8 v3

# %%
# !pip install ultralytics==8.2.0
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# The folder you are executing pip from can no longer be found.

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 524, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are {'track', 'benchmark', 'export', 'train', 'val', 'predict'}.
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'obb', 'detect', 'segment', 'pose', 'classify'}
#                 MODE (required) is one of {'track', 'benchmark', 'export', 'train', 'val', 'predict'}
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="OdAY30o3QeoNmP5wG8NV")
project = rf.workspace("uav-3rzfc").project("uav-swtpi")
version = project.version(8)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 924.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/drive/MyDrive/yolov8/v3/UAV-6/data.yaml epochs=300 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.2.19 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls /content/drive/MyDrive/yolov8/v3/UAV-6/
# Out:
# ls: cannot access '/content/drive/MyDrive/yolov8/v3/UAV-6/': No such file or directory

# %%
# !yolo task=detect mode=val model=/content/sample_data/yolov8/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.1.35 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/sample_data/yolov8/UAV-2/train/labels.cache... 68 images, 0 backgrounds, 0 corrupt: 100% 68/68 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:04<00:00,  1.08it/s]
#                    all         68         68          1      0.969      0.993      0.877
# Speed: 7.9ms preprocess, 22.2ms inference, 0.1ms loss, 11.3ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/sample_data/yolov8/runs/detect/train2/weights/best.pt conf=0.5 source={dataset.location}/test/images save_txt=true save_conf=true
# Out:
# Ultralytics YOLOv8.1.35 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/9 /content/sample_data/yolov8/UAV-2/test/images/scene00001_png.rf.226437fdb92a56a24db8233fd45ab667.jpg: 640x640 1 UAV, 37.1ms
# image 2/9 /content/sample_data/yolov8/UAV-2/test/images/scene00361_png.rf.2022f276090ad65cea1523d8f5249d11.jpg: 640x640 1 UAV, 37.1ms
# image 3/9 /content/sample_data/yolov8/UAV-2/test/images/scene00631_png.rf.34738f86a6d6e0784ed0f2cd920592f6.jpg: 640x640 1 UAV, 37.1ms
# image 4/9 /content/sample_data/yolov8/UAV-2/test/images/scene00781_png.rf.9fa2eba40abfe3b9bb72c830ee4ddd68.jpg: 640x640 1 UAV, 37.1ms
# image 5/9 /content/sample_data/yolov8/UAV-2/test/images/scene01141_png.rf.0b859ccab5cf2e1b72f09517427664ff.jpg: 640x640 1 UAV, 37.0ms
# image 6/9 /content/sample_data/yolov8/UAV-2/test/images/scene01201_png.rf.f69f0dd5f9774afd3596b52b3c59e6b1.jpg: 640x640 1 UAV, 23.0ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/sample_data/yolov8/runs/detect/predict*.jpg'):
      display(Image(filename=image_path, height=600))
      print("\n")
